# %% [markdown]
# <h2 style="color:darkred">1. Numeric Data Types</h2>

# %% [markdown]
# <table style="width:80%; font-size:14px; border-collapse:collapse; margin:auto;">
#     <thead>
#         <tr style="background-color:#f2f2f2;">
#             <th style="color:purple; border:1px solid #333; padding:10px;">Numeric Type</th>
#             <th style="color:purple; border:1px solid #333; padding:10px;">Description</th>
#             <th style="color:purple; border:1px solid #333; padding:10px;">Examples</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="border:1px solid #333; padding:8px;">
#                 <span style="font-weight:bold; color:#0d6efd;">Integer (int)</span>
#             </td>
#             <td style="border:1px solid #333; padding:8px;">
#                 Whole numbers, positive or negative, without decimals
#             </td>
#             <td style="border:1px solid #333; padding:8px; text-align:center;">
#                 10, -5
#             </td>
#         </tr>
#         <tr>
#             <td style="border:1px solid #333; padding:8px;">
#                 <span style="font-weight:bold; color:#198754;">Floating point (float)</span>
#             </td>
#             <td style="border:1px solid #333; padding:8px;">
#                 Numbers with decimal points or scientific notation
#             </td>
#             <td style="border:1px solid #333; padding:8px; text-align:center;">
#                 10.5, 3.14
#             </td>
#         </tr>
#         <tr>
#             <td style="border:1px solid #333; padding:8px;">
#                 <span style="font-weight:bold; color:#dc3545;">Complex (complex)</span>
#             </td>
#             <td style="border:1px solid #333; padding:8px;">
#                 Numbers with a real and an imaginary part, denoted with <b>j</b>
#             </td>
#             <td style="border:1px solid #333; padding:8px; text-align:center;">
#                 2 + 3j
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3 style="color:purple">1. Integer</h3>

# %%
i = 5     # integer declaration

# %%
type(i)   # Type check
# Out:
# int

# %%
print(i)
# Out:
# 5

# %% [markdown]
# <h3 style="color:purple">2. Float</h3>

# %%
f = 20.67 # Float declaration

# %%
type(f)   # Type check
# Out:
# float

# %%
print(f)
# Out:
# 20.67

# %% [markdown]
# <h3 style="color:purple">3. Complex</h3>

# %%
c = 10 + 20J  # can also use j but no other alpabets for imaginary part. It should be j

# %%
type(c)       # Type check
# Out:
# complex

# %%
c.real        # To get real part real attribute need to use
# Out:
# 10.0

# %%
c.imag         # To get imaginary part imag attribute need to use
# Out:
# 20.0

# %% [markdown]
# <h2 style="color:darkred">2. Boolean Data Type</h2>

# %% [markdown]
# <table style="width:70%; font-size:14px; border-collapse:collapse; margin:auto;">
#     <thead>
#         <tr style="background-color:#f2f2f2;">
#             <th style="color:purple; border:1px solid #333; padding:10px;">Type</th>
#             <th style="color:purple; border:1px solid #333; padding:10px;">Description</th>
#             <th style="color:purple; border:1px solid #333; padding:10px;">Values</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="border:1px solid #333; padding:8px;">
#                 <span style="font-weight:bold; color:#0d6efd;">Boolean (bool)</span>
#             </td>
#             <td style="border:1px solid #333; padding:8px;">
#                 Represents logical values
#             </td>
#             <td style="border:1px solid #333; padding:8px; text-align:center;">
#                 <span style="color:#198754; font-weight:bold;">True</span>,
#                 <span style="color:#dc3545; font-weight:bold;">False</span>
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <div style="width:50%; margin:auto; font-size:14px; border:1px solid #333; padding:15px; border-radius:8px; background-color:#f9f9f9;">
# 💻 Machines work using <b>1's and 0's</b><br>
# <span style="color:#198754; font-weight:bold;">True</span> = <b>1</b><br>
# <span style="color:#dc3545; font-weight:bold;">False</span> = <b>0</b>
# </div>

# %%
f = False     # Boolean False declaration

# %%
t = True      # Boolean True declaration

# %%
type(f)       # Type check
# Out:
# bool

# %%
type(t)       # Type check
# Out:
# bool

# %%
print(f)
# Out:
# False

# %%
f + t
# Out:
# 1

# %%
f - t
# Out:
# -1

# %%
f / t
# Out:
# 0.0

# %%
f // t
# Out:
# 0

# %%
f * t
# Out:
# 0

# %% [markdown]
# <h2 style="color:darkred">3. Sequence Types</h2>

# %% [markdown]
# <table style="width:80%; font-size:14px; border-collapse:collapse; margin:auto;">
#     <thead>
#         <tr style="background-color:#f2f2f2;">
#             <th style="color:purple; border:1px solid #333; padding:10px;">Type</th>
#             <th style="color:purple; border:1px solid #333; padding:10px;">Description</th>
#             <th style="color:purple; border:1px solid #333; padding:10px;">Example</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td style="border:1px solid #333; padding:8px;">
#                 <span style="color:#0d6efd; font-weight:bold;">String (str)</span>
#             </td>
#             <td style="border:1px solid #333; padding:8px;">
#                 A sequence of Unicode characters enclosed in quotes
#             </td>
#             <td style="border:1px solid #333; padding:8px; text-align:center;">
#                 "Hello"
#             </td>
#         </tr>
#         <tr>
#             <td style="border:1px solid #333; padding:8px;">
#                 <span style="color:#198754; font-weight:bold;">List (list)</span>
#             </td>
#             <td style="border:1px solid #333; padding:8px;">
#                 An ordered, mutable (changeable) collection that can hold diverse data types
#             </td>
#             <td style="border:1px solid #333; padding:8px; text-align:center;">
#                 [1, "a", 3.5]
#             </td>
#         </tr>
#         <tr>
#             <td style="border:1px solid #333; padding:8px;">
#                 <span style="color:#fd7e14; font-weight:bold;">Tuple (tuple)</span>
#             </td>
#             <td style="border:1px solid #333; padding:8px;">
#                 An ordered, immutable (unchangeable) collection
#             </td>
#             <td style="border:1px solid #333; padding:8px; text-align:center;">
#                 (1, 2, 3)
#             </td>
#         </tr>
#         <tr>
#             <td style="border:1px solid #333; padding:8px;">
#                 <span style="color:#6f42c1; font-weight:bold;">Range (range)</span>
#             </td>
#             <td style="border:1px solid #333; padding:8px;">
#                 Represents a sequence of numbers, often used in loops
#             </td>
#             <td style="border:1px solid #333; padding:8px; text-align:center;">
#                 range(1, 5)
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3 style="color:purple">1. String</h3>

# %%
ssq = 'welcome'       # string can be declared in single quotes

# %%
sdq = "welcome"       # string can be declared in double quotes

# %%
stq = '''welcome to
python programming
language'''            # string can be declared in triple quotes

# %%
stdq = """welcome to
python programming
language"""            # string can be declared in triple double quotes

# %%
type(ssq)              # Type check
# Out:
# str

# %%
type(stdq)
# Out:
# str

# %%
print(stdq)
# Out:
# welcome to
# python programming
# language

# %%
print(ssq)
# Out:
# welcome
