# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
emp = pd.read_excel(r'C:\Users\vinay agrawal\FSDS_PROJECT\Rawdata.xlsx')
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
data cleaning¶

# %%
emp['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
emp['Name'] = emp['Name'].str.replace(r'\W','',regex=True) 
emp['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
emp.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
import warnings
warnings.filterwarnings
# Out:
# <function warnings.filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)>

# %%
emp.head(1)
# Out:
#    Name         Domain       Age Location  Salary Exp
# 0  Mike  Datascience#$  34 years   Mumbai  5^00#0  2+

# %%
emp['Domain']
# Out:
# 0     Datascience#$
# 1           Testing
# 2    Dataanalyst^^#
# 3       Ana^^lytics
# 4        Statistics
# 5               NLP
# Name: Domain, dtype: object

# %%
clean_data=pd.read_csv(r'C:\Users\vinay agrawal\clean_data1.csv')

# %%
emp['Domain']=emp['Domain'].str.replace(r'\W','',regex = True)
emp
# Out:
#     Name       Domain       Age   Location   Salary      Exp
# 0   Mike  Datascience  34 years     Mumbai   5^00#0       2+
# 1  Teddy      Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst       NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim          NLP      55yr      Delhi  6000^$0      10+

# %%
emp['Location']=emp['Location'].str.replace(r'\W','',regex = True)
emp
# Out:
#     Name       Domain       Age   Location   Salary      Exp
# 0   Mike  Datascience  34 years     Mumbai   5^00#0       2+
# 1  Teddy      Testing    45' yr  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst       NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics     67-yr        NaN   30000-  5+ year
# 5    Kim          NLP      55yr      Delhi  6000^$0      10+

# %%
emp['Age']=emp['Age'].str.replace(r'\W','',regex = True)
emp['Age']
# Out:
# 0    34years
# 1       45yr
# 2        NaN
# 3        NaN
# 4       67yr
# 5       55yr
# Name: Age, dtype: object

# %%
emp['Age']=emp['Age'].str.extract('(\\d+)')#,'',regex = True)
emp['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
emp
# Out:
#     Name       Domain  Age   Location   Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5^00#0       2+
# 1  Teddy      Testing   45  Bangalore  10%%000       <3
# 2   Umar  Dataanalyst  NaN        NaN  1$5%000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad   2000^0      NaN
# 4  Uttam   Statistics   67        NaN   30000-  5+ year
# 5    Kim          NLP   55      Delhi  6000^$0      10+

# %%
emp['Salary'] = emp['Salary'].str.replace(r'\W','',regex=True)
emp['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: object

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5000       2+
# 1  Teddy      Testing   45  Bangalore  10000       <3
# 2   Umar  Dataanalyst  NaN        NaN  15000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad  20000      NaN
# 4  Uttam   Statistics   67        NaN  30000  5+ year
# 5    Kim          NLP   55      Delhi  60000      10+

# %%
clean_data
# Out:
#    Unnamed: 0   Name       Domain  Age   Location  Salary  Exp
# 0           0   Mike  Datascience   50     Mumbai       5    2
# 1           1  Teddy      Testing   50  Bangalore      10    3
# 2           2   Umar  Dataanalyst   50  Bangalore       1    4
# 3           3   Jane    Analytics   50   Hyderbad    2000    4
# 4           4  Uttam   Statistics   50  Bangalore   30000    5
# 5           5    Kim          NLP   50      Delhi    6000   10

# %%
emp.isnull()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
emp.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary      Exp
# 0   Mike  Datascience   34     Mumbai   5000       2+
# 1  Teddy      Testing   45  Bangalore  10000       <3
# 2   Umar  Dataanalyst  NaN        NaN  15000   4> yrs
# 3   Jane    Analytics  NaN   Hyderbad  20000      NaN
# 4  Uttam   Statistics   67        NaN  30000  5+ year
# 5    Kim          NLP   55      Delhi  60000      10+

# %%
emp['Exp']
# Out:
# 0         2+
# 1         <3
# 2     4> yrs
# 3        NaN
# 4    5+ year
# 5        10+
# Name: Exp, dtype: object

# %%
emp['Exp']=emp['Exp'].str.extract('(\d+)')
emp['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    NaN
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
clean_data1=emp.copy()
clean_data1
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
clean_data1['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
import numpy as np

# %%
clean_data1['Exp']=clean_data1['Exp'].fillna(np.mean(pd.to_numeric(clean_data1['Exp']

# %%
clean_data1['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    NaN
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
clean_data1['Location'].isnull().sum()
# Out:
# np.int64(2)

# %%
clean_data1['Location']=clean_data1['Location'].fillna(clean_data1['Location'].mode()[0])
clean_data1['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2    Bangalore
# 3     Hyderbad
# 4    Bangalore
# 5        Delhi
# Name: Location, dtype: object

# %%
clean_data1
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
clean_data1['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2          NaN
# 3     Hyderbad
# 4          NaN
# 5        Delhi
# Name: Location, dtype: object

# %%
clean_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
clean_data1['Age'] = clean_data1['Age'].astype(int)
clean_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      int64
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      int64
#  5   Exp       6 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 420.0+ bytes

# %%
clean_data1['Salary'] = clean_data1['Salary'].astype(int)
clean_data1['Exp'] = clean_data1['Exp'].astype(int)

# %%
clean_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      int64
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      int64
#  5   Exp       6 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 420.0+ bytes

# %%
clean_data1['Name'] = clean_data1['Name'].astype('category')
clean_data1['Domain'] = clean_data1['Domain'].astype('category')
clean_data1['Location'] = clean_data1['Location'].astype('category')

# %%
clean_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      category
#  1   Domain    6 non-null      category
#  2   Age       6 non-null      int64
#  3   Location  6 non-null      category
#  4   Salary    6 non-null      int64
#  5   Exp       6 non-null      int64
# dtypes: category(3), int64(3)
# memory usage: 938.0 bytes

# %%
clean_data1
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   50     Mumbai       5    2
# 1  Teddy      Testing   50  Bangalore      10    3
# 2   Umar  Dataanalyst   50  Bangalore       1    4
# 3   Jane    Analytics   50   Hyderbad    2000    4
# 4  Uttam   Statistics   50  Bangalore   30000    5
# 5    Kim          NLP   50      Delhi    6000   10

# %%
emp['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
clean_data1['Salary']
# Out:
# 0        5
# 1       10
# 2        1
# 3     2000
# 4    30000
# 5     6000
# Name: Salary, dtype: int64

# %%
import matplotlib.pyplot as plt # visualization
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
vis1 = sns.distplot(clean_data1['Salary'])

# %%
vis2=sns.displot(clean_data1['Salary'])

# %%
vis3=plt.hist(clean_data1['Salary'])

# %%
vis4 = sns.lmplot(data=clean_data1, x = 'Exp',y = 'Salary')

# %%
clean_data1[:]
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   50     Mumbai       5    2
# 1  Teddy      Testing   50  Bangalore      10    3
# 2   Umar  Dataanalyst   50  Bangalore       1    4
# 3   Jane    Analytics   50   Hyderbad    2000    4
# 4  Uttam   Statistics   50  Bangalore   30000    5
# 5    Kim          NLP   50      Delhi    6000   10

# %%
vis5 = sns.lmplot(data=clean_data1, x = 'Exp',y = 'Salary',fit_reg = False)

# %%
clean_data1[3:4]
# Out:
#    Name     Domain  Age  Location  Salary  Exp
# 3  Jane  Analytics   50  Hyderbad    2000    4

# %%
clean_data1[0:6:2]
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   50     Mumbai       5    2
# 2   Umar  Dataanalyst   50  Bangalore       1    4
# 4  Uttam   Statistics   50  Bangalore   30000    5

# %%
clean_data[::-1]
# Out:
#    Unnamed: 0   Name       Domain  Age   Location  Salary  Exp
# 5           5    Kim          NLP   50      Delhi    6000   10
# 4           4  Uttam   Statistics   50  Bangalore   30000    5
# 3           3   Jane    Analytics   50   Hyderbad    2000    4
# 2           2   Umar  Dataanalyst   50  Bangalore       1    4
# 1           1  Teddy      Testing   50  Bangalore      10    3
# 0           0   Mike  Datascience   50     Mumbai       5    2

# %%
clean_data1.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
y_dv = clean_data1['Salary']

# %%
y_dv
# Out:
# 0        5
# 1       10
# 2        1
# 3     2000
# 4    30000
# 5     6000
# Name: Salary, dtype: int64

# %%
x_iv = clean_data1[['Name','Domain','Age','Location','Exp']]

# %%
x_iv
# Out:
#     Name       Domain  Age   Location  Exp
# 0   Mike  Datascience   50     Mumbai    2
# 1  Teddy      Testing   50  Bangalore    3
# 2   Umar  Dataanalyst   50  Bangalore    4
# 3   Jane    Analytics   50   Hyderbad    4
# 4  Uttam   Statistics   50  Bangalore    5
# 5    Kim          NLP   50      Delhi   10

# %%
clean_data1
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   50     Mumbai       5    2
# 1  Teddy      Testing   50  Bangalore      10    3
# 2   Umar  Dataanalyst   50  Bangalore       1    4
# 3   Jane    Analytics   50   Hyderbad    2000    4
# 4  Uttam   Statistics   50  Bangalore   30000    5
# 5    Kim          NLP   50      Delhi    6000   10

# %%
imputation = pd.get_dummies(clean_data1)

# %%
imputation
# Out:
#    Age  Salary  Exp  Name_Jane  Name_Kim  Name_Mike  Name_Teddy  Name_Umar  \
# 0   50       5    2      False     False       True       False      False
# 1   50      10    3      False     False      False        True      False
# 2   50       1    4      False     False      False       False       True
# 3   50    2000    4       True     False      False       False      False
# 4   50   30000    5      False     False      False       False      False
# 5   50    6000   10      False      True      False       False      False
#
#    Name_Uttam  Domain_Analytics  Domain_Dataanalyst  Domain_Datascience  \
# 0       False             False               False                True
# 1       False             False               False               False
# 2       False             False                True               False
# 3       False              True               False               False
# 4        True             False               False               False
# 5       False             False               False               False
#
#    Domain_NLP  Domain_Statistics  Domain_Testing  Location_Bangalore  \
# 0       False              False           False               False
# 1       False              False            True                True
# 2       False              False           False                True
# 3       False              False           False               False
# 4       False               True           False                True
# 5        True              False           False               False
#
#    Location_Delhi  Location_Hyderbad  Location_Mumbai
# 0           False              False             True
# 1           False              False            False
# 2           False              False            False
# 3           False               True            False
# 4           False              False            False
# 5            True              False            False

# %%
imputation1 = pd.get_dummies(clean_data1)

# %%
imputation1
# Out:
#    Age  Salary  Exp  Name_Jane  Name_Kim  Name_Mike  Name_Teddy  Name_Umar  \
# 0   50       5    2      False     False       True       False      False
# 1   50      10    3      False     False      False        True      False
# 2   50       1    4      False     False      False       False       True
# 3   50    2000    4       True     False      False       False      False
# 4   50   30000    5      False     False      False       False      False
# 5   50    6000   10      False      True      False       False      False
#
#    Name_Uttam  Domain_Analytics  Domain_Dataanalyst  Domain_Datascience  \
# 0       False             False               False                True
# 1       False             False               False               False
# 2       False             False                True               False
# 3       False              True               False               False
# 4        True             False               False               False
# 5       False             False               False               False
#
#    Domain_NLP  Domain_Statistics  Domain_Testing  Location_Bangalore  \
# 0       False              False           False               False
# 1       False              False            True                True
# 2       False              False           False                True
# 3       False              False           False               False
# 4       False               True           False                True
# 5        True              False           False               False
#
#    Location_Delhi  Location_Hyderbad  Location_Mumbai
# 0           False              False             True
# 1           False              False            False
# 2           False              False            False
# 3           False               True            False
# 4           False              False            False
# 5            True              False            False

# %%
vis5= sns.heatmap(zx
